# %% [markdown]
# <a href="https://colab.research.google.com/github/HenryZumaeta/py4cd_EPC2025/blob/main/C13/C13_Script02_IntroPlotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ScatterPlot

# %%
# En Seaborn
import seaborn as sns
# sns.set_theme(style="darkgrid")
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, y="total_bill", x="tip", hue="day", size = "size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
from _plotly_utils.colors.qualitative import Alphabet_r
from _plotly_utils.colors.carto import Bold_r
from plotly.colors import qualitative
# Veamos cómo sería en plotly

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importemos plotly.express para crear gráficos interactivos de alto nivel
import plotly.express as px

fig = px.scatter(data_frame = tips,
                 x="tip",
                 y="total_bill",
                 color="day",
                 size = "size",
                 title = "Total Bill vs Tip (por día de la semana)",
                #  color_discrete_sequence = px.colors.qualitative.Alphabet_r
                #  color_discrete_sequence = px.colors.qualitative.Pastel
                 color_discrete_sequence = px.colors.qualitative.Bold_r

                )

# Mostrar el gráfico interactivo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
help(px.scatter)
# Out:
# Help on function scatter in module plotly.express._chart_types:
#
# scatter(data_frame=None, x=None, y=None, color=None, symbol=None, size=None, hover_name=None, hover_data=None, custom_data=None, text=None, facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, error_x=None, error_x_minus=None, error_y=None, error_y_minus=None, animation_frame=None, animation_group=None, category_orders=None, labels=None, orientation=None, color_discrete_sequence=None, color_discrete_map=None, color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, symbol_sequence=None, symbol_map=None, opacity=None, size_max=None, marginal_x=None, marginal_y=None, trendline=None, trendline_options=None, trendline_color_override=None, trendline_scope='trace', log_x=False, log_y=False, range_x=None, range_y=None, render_mode='auto', title=None, template=None, width=None, height=None) -> plotly.graph_objs._figure.Figure
# ...

# %%
# Analizar las paletas de colores por tipo

# %%
dir(px.colors.sequential)
# Out:
# ['Aggrnyl',
#  'Aggrnyl_r',
#  'Agsunset',
#  'Agsunset_r',
#  'Blackbody',
#  'Blackbody_r',
#  'Bluered',
#  'Bluered_r',
#  'Blues',
#  'Blues_r',
#  'Blugrn',
#  'Blugrn_r',
#  'Bluyl',
#  'Bluyl_r',
#  'Brwnyl',
#  'Brwnyl_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'Burg',
#  'Burg_r',
#  'Burgyl',
#  'Burgyl_r',
#  'Cividis',
#  'Cividis_r',
#  'Darkmint',
#  'Darkmint_r',
#  'Electric',
#  'Electric_r',
#  'Emrld',
#  'Emrld_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Hot',
#  'Hot_r',
#  'Inferno',
#  'Inferno_r',
#  'Jet',
#  'Jet_r',
#  'Magenta',
#  'Magenta_r',
#  'Magma',
#  'Magma_r',
#  'Mint',
#  'Mint_r',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'Oryel',
#  'Oryel_r',
#  'Peach',
#  'Peach_r',
#  'Pinkyl',
#  'Pinkyl_r',
#  'Plasma',
#  'Plasma_r',
#  'Plotly3',
#  'Plotly3_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuRd',
#  'PuRd_r',
#  'Purp',
#  'Purp_r',
#  'Purples',
# ...

# %%
dir(px.colors.qualitative)
# Out:
# ['Alphabet',
#  'Alphabet_r',
#  'Antique',
#  'Antique_r',
#  'Bold',
#  'Bold_r',
#  'D3',
#  'D3_r',
#  'Dark2',
#  'Dark24',
#  'Dark24_r',
#  'Dark2_r',
#  'G10',
#  'G10_r',
#  'Light24',
#  'Light24_r',
#  'Pastel',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'Pastel_r',
#  'Plotly',
#  'Plotly_r',
#  'Prism',
#  'Prism_r',
#  'Safe',
#  'Safe_r',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'T10',
#  'T10_r',
#  'Vivid',
#  'Vivid_r',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_swatches',
#  'swatches']

# %%
# Paletas divergentes: Variables con punto mediao significativo (desviaciones, diferencias)
dir(px.colors.diverging)
# Out:
# ['Armyrose',
#  'Armyrose_r',
#  'BrBG',
#  'BrBG_r',
#  'Earth',
#  'Earth_r',
#  'Fall',
#  'Fall_r',
#  'Geyser',
#  'Geyser_r',
#  'PRGn',
#  'PRGn_r',
#  'PiYG',
#  'PiYG_r',
#  'Picnic',
#  'Picnic_r',
#  'Portland',
#  'Portland_r',
#  'PuOr',
#  'PuOr_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Spectral',
#  'Spectral_r',
#  'Tealrose',
#  'Tealrose_r',
#  'Temps',
#  'Temps_r',
#  'Tropic',
#  'Tropic_r',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_swatches',
#  '_swatches_continuous',
#  'balance',
#  'balance_r',
#  'curl',
#  'curl_r',
#  'delta',
#  'delta_r',
#  'oxy',
#  'oxy_r',
#  'swatches',
#  'swatches_continuous']

# %%
# Paletas de colores para variables periódicas
dir(px.colors.cyclical)
# Out:
# ['Edge',
#  'Edge_r',
#  'HSV',
#  'HSV_r',
#  'IceFire',
#  'IceFire_r',
#  'Phase',
#  'Phase_r',
#  'Twilight',
#  'Twilight_r',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_swatches',
#  '_swatches_continuous',
#  '_swatches_cyclical',
#  'mrybm',
#  'mrybm_r',
#  'mygbm',
#  'mygbm_r',
#  'swatches',
#  'swatches_continuous',
#  'swatches_cyclical']

# %%
# Mapas de colores para información espacial y cartográficas
dir(px.colors.carto)
# Out:
# ['Aggrnyl',
#  'Aggrnyl_r',
#  'Agsunset',
#  'Agsunset_r',
#  'Antique',
#  'Antique_r',
#  'Armyrose',
#  'Armyrose_r',
#  'Blugrn',
#  'Blugrn_r',
#  'Bluyl',
#  'Bluyl_r',
#  'Bold',
#  'Bold_r',
#  'Brwnyl',
#  'Brwnyl_r',
#  'Burg',
#  'Burg_r',
#  'Burgyl',
#  'Burgyl_r',
#  'Darkmint',
#  'Darkmint_r',
#  'Earth',
#  'Earth_r',
#  'Emrld',
#  'Emrld_r',
#  'Fall',
#  'Fall_r',
#  'Geyser',
#  'Geyser_r',
#  'Magenta',
#  'Magenta_r',
#  'Mint',
#  'Mint_r',
#  'Oryel',
#  'Oryel_r',
#  'Pastel',
#  'Pastel_r',
#  'Peach',
#  'Peach_r',
#  'Pinkyl',
#  'Pinkyl_r',
#  'Prism',
#  'Prism_r',
#  'Purp',
#  'Purp_r',
#  'Purpor',
#  'Purpor_r',
#  'Redor',
#  'Redor_r',
#  'Safe',
#  'Safe_r',
#  'Sunset',
#  'Sunset_r',
#  'Sunsetdark',
#  'Sunsetdark_r',
#  'Teal',
#  'Teal_r',
#  'Tealgrn',
#  'Tealgrn_r',
#  'Tealrose',
#  'Tealrose_r',
#  'Temps',
#  'Temps_r',
#  'Tropic',
#  'Tropic_r',
#  'Vivid',
#  'Vivid_r',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
# ...

# %%
# Colores que componen a una paleta de colores secuenciales ('YlGnBu')
px.colors.sequential.YlGnBu
# Out:
# ['rgb(255,255,217)',
#  'rgb(237,248,177)',
#  'rgb(199,233,180)',
#  'rgb(127,205,187)',
#  'rgb(65,182,196)',
#  'rgb(29,145,192)',
#  'rgb(34,94,168)',
#  'rgb(37,52,148)',
#  'rgb(8,29,88)']
